# %%
import pandas as pd

# %%
data4 = pd.read_excel(r"C:\Users\user\Downloads\mydata4.xlsx")

# %%
data4
# Out:
#     Name  Age  Salay
# 0  Pinky   30  20000
# 1   john   22  15000
# 2   neha   25  30000
# 3    raj   26  35000

# %%
data2 = pd.read_csv("E:\docment\mydata2.csv")

# %%
data2
# Out:
#    Roll No     Name  Batch
# 0     1001    Pinky   1840
# 1     1002     John   1043
# 2     1003   Deepak   1840
# 3     1004  Anjuman   1765

# %%
data3 = pd.read_csv("E:\docment\Mydata3.tsv",sep='\t')

# %%
data3
# Out:
#    RollNO    Name  Batch
# 0    1001   pinky   1804
# 1    1002    John   1873
# 2    1003  Deppak   1840
# 3    1004     raj   1540

# %%
data3
# Out:
#    RollNO    Name  Batch
# 0    1001   pinky   1804
# 1    1002    John   1873
# 2    1003  Deppak   1840
# 3    1004     raj   1540
